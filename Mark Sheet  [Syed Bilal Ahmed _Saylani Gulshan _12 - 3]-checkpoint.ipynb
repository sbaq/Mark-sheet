# %%
def result():
    
    print()
    
    obtained_marks = maths_marks + phy_marks + comp_marks + eng_marks + urdu_marks 

    percentage = ( obtained_marks / 500 ) * 100
    roundoff = round(percentage,2)
    
    print("******** RESULT CARD *********\n______________________________\n")
    print("Name: " + std_name + "\nRoll No: " + str(std_no) + "\n______________________________\n")
    print("Total marks: 500 \nObtained marks: " + str(obtained_marks) + "\nPercentage: " + str(roundoff))

    
    if percentage >= 80 :
        print("Grade: A \n______________________________\n")
        
        
        if maths_marks < 50 :
            print("Fail in Maths.")
        if phy_marks < 50 :
            print("Fail in Physics.")
        if comp_marks < 50 :
            print("Fail in Computer.")
        if eng_marks < 50 :
            print("Fail in English.")
        if urdu_marks < 50 :
            print("Fail in Urdu.")

        print("______________________________")

        
    elif percentage >= 70 :
        print("Grade: B \n______________________________\n")

        
        if maths_marks < 50 :
            print("Fail in Maths.")
        if phy_marks < 50 :
            print("Fail in Physics.")
        if comp_marks < 50 :
            print("Fail in Computer.")
        if eng_marks < 50 :
            print("Fail in English.")
        if urdu_marks < 50 :
            print("Fail in Urdu.")

        print("______________________________")


    elif percentage >= 60 :
        print("Grade: C \n______________________________\n")      
            
            
        if maths_marks < 50 :
            print("Fail in Maths.")
        if phy_marks < 50 :
            print("Fail in Physics.")
        if comp_marks < 50 :
            print("Fail in Computer.")
        if eng_marks < 50 :
            print("Fail in English.")
        if urdu_marks < 50 :
            print("Fail in Urdu.")

        print("______________________________")



    elif percentage >= 50 :
        print("Grade: D \n______________________________\n")

        
        if maths_marks < 50 :
            print("Fail in Maths.")
        if phy_marks < 50 :
            print("Fail in Physics.")
        if comp_marks < 50 :
            print("Fail in Computer.")
        if eng_marks < 50 :
            print("Fail in English.")
        if urdu_marks < 50 :
            print("Fail in Urdu.")

        print("______________________________")
            
            
    else :
        print("Grade: F \n______________________________")

# %%
def check():

    if maths_marks > 100 or phy_marks > 100 or comp_marks > 100 or eng_marks > 100 or urdu_marks > 100 :
        print("\nMarks can't be greater than 100.")    

    if maths_marks < 0 or phy_marks < 0 or comp_marks < 0 or eng_marks < 0 or urdu_marks < 0 :
        print("\nMarks can't be less than 0.")

    else:
        result()

# %%
std_name = input("Enter your name: ")
std_no = int(input("Enter student no: "))

print()

maths_marks = int(input("Enter the marks of Maths: "))
phy_marks = int(input("Enter the marks of Physics: "))
comp_marks = int(input("Enter the marks of Computer: "))
eng_marks = int(input("Enter the marks of English: "))
urdu_marks = int(input("Enter the marks of Urdu: "))


check()
# Out:
# Enter your name: Bilal
# Enter student no: 4789
#
# Enter the marks of Maths: 100
# Enter the marks of Physics: 49
# Enter the marks of Computer: 50
# Enter the marks of English: 64
# Enter the marks of Urdu: 31
#
# ******** RESULT CARD *********
# ______________________________
#
# Name: Bilal
# Roll No: 4789
# ______________________________
#
# Total marks: 500
# Obtained marks: 294
# Percentage: 58.8
# Grade: D
# ______________________________
#
# Fail in Physics.
# Fail in Urdu.
# ______________________________
